# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshvarma3366/pythonlab1/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("LOKESH")
# Out:
# LOKESH

# %%
print(2+2)
# Out:
# 4

# %%
print("surya")
# Out:
# surya

# %%
a=4
print(a)
# Out:
# 4

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
b=1.2
print(type(b))
# Out:
# <class 'float'>

# %%
c="lokesh"
print(type(c))
# Out:
# <class 'str'>

# %%
a=input()
# Out:
# 10

# %%
a
# Out:
# '10'

# %% [markdown]
# in output to not get "" we should give like int,float

# %%
a=int(input())
# Out:
# 10

# %%
a
# Out:
# 10

# %%
a=float(input())
# Out:
# 1.5

# %%
a
# Out:
# 1.5

# %%
print(6/5)
# Out:
# 1.2

# %%
print(6//5)
# Out:
# 1

# %%
print(2*3)
# Out:
# 6

# %%
print(6%3)
# Out:
# 0

# %%
print(2**3)
# Out:
# 8

# %%
print(3**2)
# Out:
# 9

# %% [markdown]
# **   means power
