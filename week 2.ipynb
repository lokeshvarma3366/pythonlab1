# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshvarma3366/pythonlab1/blob/main/week%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #for loop in python

# %%
for(i=0;i<=4;i++)
range(start,end,diff)for i range (1,11)
# Out:
#   File "/tmp/ipykernel_1501/2249481656.py", line 1
#     for(i=0;i<=4;i++)
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
for i in range(1,13):
  print("python")
# Out:
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python
# python

# %%
n=int(input())
for i in range(n):
  print(i,end="")
# Out:
# 15
# 01234567891011121314

# %% [markdown]
# #print 1 to n odd

# %%
n=int(input())
for i in range(1,n+1,2):
  print(i,end="")
# Out:
# 5
# 135

# %%
#PRINT TABLE MULTIPLICATION
n=int(input())
for i in range(1,21):
  print(f"{n}*{i}={n*i}")
# Out:
# 7
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# 7*10=70
# 7*11=77
# 7*12=84
# 7*13=91
# 7*14=98
# 7*15=105
# 7*16=112
# 7*17=119
# 7*18=126
# 7*19=133
# 7*20=140

# %%
#check given number is prime or not
n=int(input())
for i in range(2,n):
  if(i%n==0):
    print("its prime number")
  else:
    print("not print")
# Out:
# 5
# not print
# not print
# not print

# %%
#print prime number between two numbers
a=int(input())
b=int(input())
for i in range(a,b+1):
 for j in range(2,i):
  if(i%j==0):
    break
  else:
    print(i,end="")
# Out:
# 1
# 10
# 3555777779

# %%
#print sum of numbers
n=int(input())
sum=0
while(n!=0):
  rem=n%10
  sum=sum+rem
  n=n//10
print(sum)
# Out:
# 345
# 12

# %%
#repeated numbers
for i in range(1,11):
 for j in range(1,11):
  print(j,end="")
print()
# Out:
# 12345678910123456789101234567891012345678910123456789101234567891012345678910123456789101234567891012345678910
